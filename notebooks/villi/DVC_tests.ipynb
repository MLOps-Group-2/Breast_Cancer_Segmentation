# %%
from dvc.api import DVCFileSystem

# %%
url = "gs://bcss-dvc-datasets"
fs = DVCFileSystem(url)

# %%
type(fs)
# Out:
# dvc.fs.dvc._DVCFileSystem

# %%
dict(fs)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 dict(fs)
#
# TypeError: '_DVCFileSystem' object is not iterable

# %%
fs.get("BCSS", "BCSS", recursive=True)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~/anaconda3/envs/breast_cancer_segmentation/lib/python3.11/site-packages/scmrepo/git/backend/dulwich/__init__.py:267, in DulwichBackend.clone(cls, url, to_path, shallow_branch, progress, bare, mirror)
#     266 else:
# --> 267     repo = clone_from()
#     269 with closing(repo):
#
# File ~/anaconda3/envs/breast_cancer_segmentation/lib/python3.11/site-packages/dulwich/porcelain.py:546, in clone(source, target, bare, checkout, errstream, outstream, origin, depth, branch, config, **kwargs)
#     544 (client, path) = get_transport_and_path(source, config=config, **kwargs)
# --> 546 return client.clone(
#     547     path,
#     548     target,
#     549     mkdir=mkdir,
#     550     bare=bare,
#     551     origin=origin,
#     552     checkout=checkout,
#     553     branch=branch,
#     554     progress=errstream.write,
# ...
